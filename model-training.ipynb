# %%
from laplace_dataset import LaplaceProblemDataset, split_data
from models import LaplaceModel, train
import torch

# %%
dataset = LaplaceProblemDataset('data/data_4x4_50_0.txt', 10)

# %%
train_dataloader, validation_dataloader, test_dataloader = split_data(dataset)

# %%
non_dct_model = LaplaceModel(
    n=2000, 
    input_size=dataset.input_size(), 
    output_size=dataset.output_size(),
    isDCT=False,
    optimizer='SGD',
    learning_rate=1e-5,
    device=torch.device('cpu'))

# %%
dct_model = LaplaceModel(
    n=2000, 
    input_size=dataset.input_size(), 
    output_size=dataset.output_size(),
    isDCT=True,
    optimizer='SGD',
    learning_rate=1e-5,
    device=torch.device('cpu'))

# %%
train([non_dct_model, dct_model], train_dataloader, validation_dataloader, epochs=1000, stopping_loss=0.068)
# Out:
# Epoch: 0
#   Non-DCT Training Loss: 670.5006225585937 Validation Loss: 690.0950622558594 Epoch Duration: 1.4172327518463135
#   DCT Training Loss: 650.2219848632812 Validation Loss: 664.4312438964844 Epoch Duration: 1.3959317207336426
# Epoch: 1
#   Non-DCT Training Loss: 612.6602172851562 Validation Loss: 661.5616455078125 Epoch Duration: 1.322291374206543
#   DCT Training Loss: 595.6056396484375 Validation Loss: 639.9954528808594 Epoch Duration: 1.4173855781555176
# Epoch: 2
#   Non-DCT Training Loss: 568.280078125 Validation Loss: 639.6636047363281 Epoch Duration: 1.351269006729126
#   DCT Training Loss: 553.7517333984375 Validation Loss: 621.3070983886719 Epoch Duration: 1.3717641830444336
# Epoch: 3
#   Non-DCT Training Loss: 533.0576049804688 Validation Loss: 622.6672668457031 Epoch Duration: 1.355081558227539
#   DCT Training Loss: 521.0115051269531 Validation Loss: 606.8438720703125 Epoch Duration: 1.4099154472351074
# Epoch: 4
# ...
